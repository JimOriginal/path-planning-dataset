# %%
# 针对 test data中的加粗label与2pix不一致

import os
import cv2
import numpy as np
import torch
def collect_files(datapath):
    for entry in os.scandir(os.path.abspath(datapath)):
        if os.path.isfile(entry.path):
            yield entry.path
        elif os.path.isdir(entry.path):
            for nested_entry in collect_files(entry.path):
                yield nested_entry

def read_binaryjpg_2_tensor(jpg_path):
    img = cv2.imread(jpg_path, cv2.IMREAD_GRAYSCALE) # shape =(201, 201), uint8
    # color img
    #img = cv2.imread(jpg_path, cv2.IMREAD_COLOR) # shape =(201, 201, 3), uint8 # RGP
    #img = img.astype(np.int16)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img)
    #img = (img / 255)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img*255)
    resized_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_color_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_img > 100 -> 1 else 0 
    resized_img = (resized_img > 100).astype(np.int32)
    # [256,256,3] -> [3,256,256]
    #resized_img = np.transpose(resized_img, (2, 0, 1))
    
    img = torch.tensor(resized_img, dtype=torch.int32)
    
    return img

def read_rgbjpg_2_tensor(jpg_path):
    #img = cv2.imread(jpg_path, cv2.IMREAD_GRAYSCALE) # shape =(201, 201), uint8
    # color img
    img = cv2.imread(jpg_path, cv2.IMREAD_COLOR) # shape =(201, 201, 3), uint8 # RGP
    #img = img.astype(np.int16)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img)
    #img = (img / 255)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img*255)
    resized_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_color_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_img > 100 -> 1 else 0 
    #resized_img = (resized_img > 100).astype(np.int32)
    # [256,256,3] -> [3,256,256]
    resized_img = np.transpose(resized_img, (2, 0, 1))
    
    img = torch.tensor(resized_img, dtype=torch.int32)
    
    return img
root_path = 'F:\proj_rlpp\datasets\PPD\\TEST\\UNSEEN'
map_root_path = 'F:\proj_rlpp\datasets\\PPD\TEST\\UNSEEN\MAP [EXAMPLE]'

maps = list(collect_files(map_root_path))
ids_all = [os.path.basename(map_path).split('.')[0] for map_path in maps]
GREEN = np.array((0, 255, 0), dtype=np.uint8)
for ids in ids_all:
    map_path = os.path.join(root_path, 'MAP [EXAMPLE]', ids + '.jpg')
    coor_path = os.path.join(root_path, 'COORDINATE [TARGET&GOAL]', ids + '.txt')
    path2PIX_path = os.path.join(root_path, 'PATH [2PIXEL]', ids + '.jpg')
    path20PIX_path = os.path.join(root_path, 'PATH [20PIXEL]_RE', ids + '.png')



    map_sample = read_rgbjpg_2_tensor(map_path) # rgb
    path2PIX = read_binaryjpg_2_tensor(path2PIX_path) # 0 or 255| 201*201
    path20PIX = read_binaryjpg_2_tensor(path20PIX_path) # 0 or 255| 201*201

    map_array = map_sample.numpy()
    path2PIX_array = path2PIX.numpy()
    path20PIX_array = path20PIX.numpy()

    path20 = torch.nonzero(path20PIX > 0).cpu().numpy()
    path2 = torch.nonzero(path2PIX > 0).cpu().numpy()

    # (3,256,256) -> (256,256,3)
    map_array = np.transpose(map_array, (1, 2, 0))

    map_array[path20[:, 0], path20[:, 1]] = GREEN

    cv2.imwrite(f'F:\proj_rlpp\datasets\PPD\TEST\\UNSEEN\show\map_{ids}.png', map_array)

    #start, goal = MapSample_guide.read_points_from_file(coor_path)

    print('tmp')
# Out:
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# tmp
# ...

# %%
# 修改，读取path2pix。dilate to 20pix
# 针对 test data中的加粗label与2pix不一致

import os
import cv2
import numpy as np
import torch
def collect_files(datapath):
    for entry in os.scandir(os.path.abspath(datapath)):
        if os.path.isfile(entry.path):
            yield entry.path
        elif os.path.isdir(entry.path):
            for nested_entry in collect_files(entry.path):
                yield nested_entry

def read_binaryjpg_2_tensor(jpg_path):
    img = cv2.imread(jpg_path, cv2.IMREAD_GRAYSCALE) # shape =(201, 201), uint8
    # color img
    #img = cv2.imread(jpg_path, cv2.IMREAD_COLOR) # shape =(201, 201, 3), uint8 # RGP
    #img = img.astype(np.int16)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img)
    #img = (img / 255)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img*255)
    resized_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_color_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_img > 100 -> 1 else 0 
    resized_img = (resized_img > 100).astype(np.int32)
    # [256,256,3] -> [3,256,256]
    #resized_img = np.transpose(resized_img, (2, 0, 1))
    
    img = torch.tensor(resized_img, dtype=torch.int32)
    
    return img

def read_rgbjpg_2_tensor(jpg_path):
    #img = cv2.imread(jpg_path, cv2.IMREAD_GRAYSCALE) # shape =(201, 201), uint8
    # color img
    img = cv2.imread(jpg_path, cv2.IMREAD_COLOR) # shape =(201, 201, 3), uint8 # RGP
    #img = img.astype(np.int16)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img)
    #img = (img / 255)
    #cv2.imwrite('/opt/data/private/jim_private/projs/proj_rlpp/dev_output/img.jpg', img*255)
    resized_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_color_img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
    #resized_img > 100 -> 1 else 0 
    #resized_img = (resized_img > 100).astype(np.int32)
    # [256,256,3] -> [3,256,256]
    resized_img = np.transpose(resized_img, (2, 0, 1))
    
    img = torch.tensor(resized_img, dtype=torch.int32)
    
    return img
root_path = 'F:\proj_rlpp\datasets\PPD\\TEST\\UNSEEN'
map_root_path = 'F:\proj_rlpp\datasets\\PPD\TEST\\UNSEEN\MAP [EXAMPLE]'

maps = list(collect_files(map_root_path))
ids_all = [os.path.basename(map_path).split('.')[0] for map_path in maps]
GREEN = np.array((0, 255, 0), dtype=np.uint8)
for ids in ids_all:
    #map_path = os.path.join(root_path, 'MAP [EXAMPLE]', ids + '.jpg')
    #coor_path = os.path.join(root_path, 'COORDINATE [TARGET&GOAL]', ids + '.txt')
    path2PIX_path = os.path.join(root_path, 'PATH [2PIXEL]', ids + '.jpg')
    #path20PIX_path = os.path.join(root_path, 'PATH [20PIXEL]', ids + '.jpg')


    path2PIX = read_binaryjpg_2_tensor(path2PIX_path) # 0 or 255| 201*201
    path2PIX_array = path2PIX.numpy().astype(np.uint8)
    kernel = np.uint8(np.ones((25,25))) #30，25, 20
    label_binary_dilate = cv2.dilate(path2PIX_array,kernel)



    cv2.imwrite(f'F:\proj_rlpp\datasets\PPD\TEST\\UNSEEN\PATH [20PIXEL]_RE\{ids}.png', label_binary_dilate*255)

    #start, goal = MapSample_guide.read_points_from_file(coor_path)

    print('tmp')
